# %% [markdown]
# <a href="https://colab.research.google.com/github/Fukan1/Medical-AI-Pre-Abroad/blob/main/00_environment_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, 医疗AI！")
# Out:
# Hello, 医疗AI！
